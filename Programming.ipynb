# %% [markdown]
# <a href="https://colab.research.google.com/github/vardhankorada/datasharing/blob/master/Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Getting an Interview**
#
# Start applying as soon as possible. Don't wait for your course to complete. It will take few months for a interviewer to getback. So apply way before. Increase your chances of getting a interview
#
# Setup all your things before interview within a week. Following are some things to brushup before applying.
# 1. Resume
# 2. LinkedIn (Keep changing something every couple days, may be space or something, while looking for a job)
# 3. Portfolio (use pre made templates, what is in them is important, not how it is made)
# 4. Email Writing
#
# *10s* is the average time someone looks at a resume. Resume is a way to get interview, don't spend more than a day to complete it. Use keywords from their own presentations or ad postings. Make it personal for that company (may be use their name somewhere in the resume!!).
#
# Resume should be one page, relevant skills from the keywords of the presentation should be there, personalize it, having a online link for that resume, portfolio, website showcasing your work will be great.
#
# **Resume cheatsheet:**
# 1. Use a pre-designed template
# 2. Make the resume fit on one page
# 3. Include words from job description in your objective or skills (like JS developer or research analyst etc..)
# 4. Include company name you are applying to (may be)
# 5. Have online links
# 6. Remove 'I' from the entire resume
# 7. First item on the resume should be having relevance to the job you are applying and must have high value (Eg: Published AI paper in International conference.. Must not be something like HTML developer).
# 8. No buzzwords about self
# 9. Action words like testing, deploying, maintaining should be there
# 10. Measure your imapct in case of work-experience
# 11. No typos or bad grammar
# 12. Only impressive things
# 13. Technical skills should include whatever they are looking for. Mention no. of years only if it is impressive.
#
# We may need to overcome the lack of experience via something else before applying. Experience can be demonstrated by doing atleast 2 out of 4 of follwing.
# 1. GitHub -- Proves we actually code. Make sure you have good commit history, may be participate in open source projects  (https://www.youtube.com/watch?v=ktN5tDfQ_g8)
# 2. Website -- Show casing past projects, skills
# 3. 1-2 Big Projects
# 4. Blog
#
# Don't apply for jobs you are already comfortable with completely (may be if you really need money, then apply). Job Descriptions are made out more difficult to weed out junior developers. Every application should be a long shot.
# ZTM is recognized as a school. Make sure to add that to your linkedin profile.
# Don't apply via company portals, send emails via referrals, higher the salary, more the networking will take you there.
#
# **Sample Email:**
#
# Hey BOB,
#
# I saw your presentation at CONFERENCE last year on Youtube (rr point to some work they have done).
#
# Great stuff; loved what you did with FOO, in particular, comment about what your are talking about with proof. I'm also a FOO developer. I noticed that your company is hiring or ROLE. I’d love to be a part of your team. Do you have a few minutes to chat on Thursday about what you guys are doing?
#
# Thanks,
# Your Profile Link

# %% [markdown]
# # **Big O**
#
# Tells how well a problem can be solved. A good code is readable and scalable. Scalability of a code is measured using O().
#
# Rules for defining O():
# 1. Always go for worst case
# 2. Drop constants
# 3. Use different variables for differrent inputs
# 4. Drop non-dominant terms
#
# https://www.bigocheatsheet.com/
#
# n! --> When no. of nested loops = input size
#
# Variables, Data Structures, Function Calls, Allocations are all to be considered when calculating space complexity. We don't care how big the input is when calculating space complexity. We only care about extra space we are using.

# %% [markdown]
# # **How To Solve Coding Problems**
#
# You should be able to provide more value to a company than you are being paid. Companies look for the people who solve the problems, because that is what makes companies money. Analytical Skills, Coding Skills, Technical Skills, Communication Skills are what an interviewer looks in a candidate. Understand the why of solving a problem. Why that particular solution worked for that problem.
#
# The following are concepts, that are needed to be learned.
#
# **Data Structures:**
# 1. Arrays
# 2. Stacks
# 3. Queues
# 4. Linked Lists
# 5. Trees
# 6. Tries
# 7. Graphs
# 8. Hash Tables
#
# **Algorithms:**
# 1. Sorting
# 2. Dynamic Programming
# 3. BFS + DFS (Searching)
# 4. Recursion
#
# Knowing these may be of no use to your job, but this is what is used to weed out non-hardworking people for an interview. Follow below steps to solve a problem.
#
# 1. When an interviewer says the problem, write all the key details at the top, like sorted array, non-decreasing etc... This will show how organized you are.
# 2. Make sure to to double check with the interviewer about the inputs and the outputs
# 3. What is the most important value of the problem? How much time, space and memory you have?
# 4. Don't be annoying and ask too many questions.
# 5. Start with naive brute force approach. First thing that comes to your mind. No need to code for this. This shows you are thingking critically and well.
# 6. Tell them why this approach is not better (take O(n^2) or will be not very readable or something like that.)
# 7. Walk through your approach and try to comment and break things. Focus on bottle necks  ( on with highest time complexity) and repeated calculations.
# 8. Write down the steps you are going to follow before starting to code.
# 9. Modularize your code from very beginning and comment.
# 10. Start writing your code and functions. If you don't know how to solve particular method of the proble, just wirte a dummy for it. Organize your thoughts before starting to write.
# 11. Don't use confusing names like i and j.
# 12. Think about error checks in the functions, check for all the possible input scenarios. Comment what checks you are going to write.
# 13. Test your code: Check for no params, 0, null, aysnc, large arrays etc..
# 14. Talk to the interviewer about how to improve the code, tell him what part you might google to get a better solution, ask him what is the most intresting soultion he saw for this problem.
# 15. If a interviewer asks for the solution to large data sets, as an extension, then tell him or rather  show him, the divide and conquer approach ofreading only chunks of input at a time, writing output back to disk and later combining them.
#
# **Summary:**
#
# 1. Think out loud
# 2. Ask for clarifications
# 3. Think about edge cases
# 4. Test right there
# 5. Talk before writing anything

# %% [markdown]
# # **Data Structures Intro**
#
# DS + Algo = Programs
#
# A DS is a collection of values or objects. Its a container of objects. Each kind of container has it own method for retreving and storing data. Interviewers love talking about DS. How to build a DS and how to use it are the questions to answer. The second part in particular is more important.
#
# Searching, Sorting, Insertion, Deletion, Retreival are operations on DS. DS used in java are:
#
# 1. Arrays: Built In
# 2. Dynamic Arrays: ArrayList
# 3. Linked List: LinkedList
# 4. Stacks: Stack
# 5. Queues: LinkedList
# 6. PriorityQueues: PriorityQueue
# 7. Deques: LinkedList
# 8. Associative Arrays: HashTable, LinkedHashMap, HashMap, TreeMap, ConcurrentHashMap
# 9. Sets: Hashset, Treeset
# 10. Graphs: Doesn't exist in any language
#
# *Algorithms and DS to learn are: Arrays, LinkedLists, Stacks, Queues, Trees, Tries, Graphs, Hash Tables, Sorting, Dynamic Programming, BFS + DFS + Searching, Recursion*

# %% [markdown]
# # **Arrays**
#
# * Lookup : O(1)
# * Push : O(1) // If we can directly add at the end without iterating (not possible even if dynamic arrays are used when adding more elements constantly. It will become O(n)).
# * Insert : O(n)
# * Delete : O(n)
#
# Arrays can be static or dynamic. Static arrays are fixed in size. We usually use dynamic arrays in interviews. Treat String questions as Array questions.
#
#
# For reversal of a string follwing code can be used:
#
# ```
# import java.util.Scanner;
# public class Arrays {
#   public static void main(String[] args) {
#     System.out.println("Please enter a string: ");
#     Scanner sc = new Scanner(System.in);
#     String sent = sc.nextLine();
#     sc.close();
#     System.out.print(reverseString(sent));
#   }
#   public static String reverseString(String sent) {
#     StringBuilder sb = new StringBuilder();
#     for(int i = sent.length()-1; i>=0; i--)
#         sb.append(sent.charAt(i));
#     return sb.toString();
#   }
#   public static String reverseString2(String sent) {
#     return new StringBuilder(sent).reverse().toString();
#   }
# }
#
# ```
#  For merging of two sorted arrays, foolwing code can be used:
#
#
#
# ```
# public class Arrays {
#   public static void main(String[] args) {
#     int[] arr1 = new int[]{0,3,4,31};
#     int[] arr2 = new int[]{4,6,30};
#     int[] merged = mergeSortedArrays(arr1,arr2);
#     for(int ind = 0; ind<merged.length; ind++)
#       System.out.println(merged[ind]);
#   }
#  public static int[] mergeSortedArrays(int[] arr1, int[] arr2) {
#     if(arr1.length == 0)
#         return arr2;
#     else if(arr2.length == 0)
#         return arr1;
#     int[] merged = new int[arr1.length+arr2.length];
#     int i = 0,j=0,k=0;
#     while(i<arr1.length && j<arr2.length) {
#       if(arr1[i]<arr2[j])
#           merged[k++] = arr1[i++];
#       else
#           merged[k++] = arr2[j++];
#     }
#     while(i<arr1.length)
#       merged[k++] = arr1[i++];
#     while(i<arr2.length)
#       merged[k++] = arr2[j++];
#     return merged;
#   }
# }
#
# ```
